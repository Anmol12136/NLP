# %%
from nltk import pos_tag
from nltk import RegexpParser
from nltk.tokenize import word_tokenize
text = """Kratos, his deep voice resonating, spoke to his son Atreus with a stern yet caring tone, "Boy, you must heed my words. We are not gods, nor are we mortals. We walk the path in between, and that demands discipline." Atreus, eager to prove himself, responded with youthful defiance, "But Father, I can handle it! I'm not a child anymore." Kratos, recalling his own tumultuous journey, retorted, "You are not ready. The gods will test you, and the consequences of arrogance are severe." As they ventured through the treacherous realms, the echoes of their dialogues revealed a complex father-son dynamic, blending vulnerability with strength, shaping their epic odyssey in the world of gods and monsters."""

tokens = word_tokenize(text)
tokens_tag = pos_tag(tokens)
tokens_tag
# Out:
# [('Kratos', 'NNP'),
#  (',', ','),
#  ('his', 'PRP$'),
#  ('deep', 'JJ'),
#  ('voice', 'NN'),
#  ('resonating', 'NN'),
#  (',', ','),
#  ('spoke', 'VBD'),
#  ('to', 'TO'),
#  ('his', 'PRP$'),
#  ('son', 'NN'),
#  ('Atreus', 'NNP'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('stern', 'JJ'),
#  ('yet', 'RB'),
#  ('caring', 'VBG'),
#  ('tone', 'NN'),
#  (',', ','),
#  ('``', '``'),
#  ('Boy', 'NNP'),
#  (',', ','),
#  ('you', 'PRP'),
#  ('must', 'MD'),
#  ('heed', 'VB'),
#  ('my', 'PRP$'),
#  ('words', 'NNS'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('are', 'VBP'),
#  ('not', 'RB'),
#  ('gods', 'NNS'),
#  (',', ','),
#  ('nor', 'CC'),
#  ('are', 'VBP'),
#  ('we', 'PRP'),
#  ('mortals', 'NNS'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('walk', 'VBP'),
#  ('the', 'DT'),
#  ('path', 'NN'),
#  ('in', 'IN'),
#  ('between', 'IN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('that', 'IN'),
#  ('demands', 'VBZ'),
#  ('discipline', 'NN'),
#  ('.', '.'),
#  ("''", "''"),
#  ('Atreus', 'NNP'),
#  (',', ','),
#  ('eager', 'NN'),
#  ('to', 'TO'),
#  ('prove', 'VB'),
#  ('himself', 'PRP'),
#  (',', ','),
#  ('responded', 'VBD'),
#  ('with', 'IN'),
#  ('youthful', 'JJ'),
#  ('defiance', 'NN'),
#  (',', ','),
#  ('``', '``'),
#  ('But', 'CC'),
#  ('Father', 'NNP'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('can', 'MD'),
#  ('handle', 'VB'),
#  ('it', 'PRP'),
#  ('!', '.'),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ('not', 'RB'),
#  ('a', 'DT'),
#  ('child', 'NN'),
#  ('anymore', 'RB'),
#  ('.', '.'),
#  ("''", "''"),
#  ('Kratos', 'NNP'),
#  (',', ','),
#  ('recalling', 'VBG'),
#  ('his', 'PRP$'),
#  ('own', 'JJ'),
#  ('tumultuous', 'JJ'),
#  ('journey', 'NN'),
#  (',', ','),
#  ('retorted', 'VBD'),
#  (',', ','),
#  ('``', '``'),
#  ('You', 'PRP'),
#  ('are', 'VBP'),
#  ('not', 'RB'),
#  ('ready', 'JJ'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('gods', 'NNS'),
#  ('will', 'MD'),
#  ('test', 'VB'),
#  ('you', 'PRP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('consequences', 'NNS'),
#  ('of', 'IN'),
#  ('arrogance', 'NN'),
#  ('are', 'VBP'),
#  ('severe', 'JJ'),
#  ('.', '.'),
#  ("''", "''"),
#  ('As', 'IN'),
#  ('they', 'PRP'),
#  ('ventured', 'VBD'),
#  ('through', 'IN'),
#  ('the', 'DT'),
#  ('treacherous', 'JJ'),
#  ('realms', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('echoes', 'NNS'),
#  ('of', 'IN'),
#  ('their', 'PRP$'),
#  ('dialogues', 'NNS'),
#  ('revealed', 'VBD'),
#  ('a', 'DT'),
#  ('complex', 'JJ'),
#  ('father-son', 'JJ'),
#  ('dynamic', 'NN'),
#  (',', ','),
#  ('blending', 'VBG'),
#  ('vulnerability', 'NN'),
#  ('with', 'IN'),
#  ('strength', 'NN'),
#  (',', ','),
#  ('shaping', 'VBG'),
#  ('their', 'PRP$'),
#  ('epic', 'NN'),
#  ('odyssey', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('of', 'IN'),
#  ('gods', 'NNS'),
#  ('and', 'CC'),
#  ('monsters', 'NNS'),
#  ('.', '.')]

# %%
patterns= "NP: {<DT>?<JJ>*<NN>}"
chunker = RegexpParser(patterns)
chunks = chunker.parse(tokens_tag)

# %%
list(chunks.subtrees())
# Out:
# [Tree('S', [('Kratos', 'NNP'), (',', ','), ('his', 'PRP$'), Tree('NP', [('deep', 'JJ'), ('voice', 'NN')]), Tree('NP', [('resonating', 'NN')]), (',', ','), ('spoke', 'VBD'), ('to', 'TO'), ('his', 'PRP$'), Tree('NP', [('son', 'NN')]), ('Atreus', 'NNP'), ('with', 'IN'), ('a', 'DT'), ('stern', 'JJ'), ('yet', 'RB'), ('caring', 'VBG'), Tree('NP', [('tone', 'NN')]), (',', ','), ('``', '``'), ('Boy', 'NNP'), (',', ','), ('you', 'PRP'), ('must', 'MD'), ('heed', 'VB'), ('my', 'PRP$'), ('words', 'NNS'), ('.', '.'), ('We', 'PRP'), ('are', 'VBP'), ('not', 'RB'), ('gods', 'NNS'), (',', ','), ('nor', 'CC'), ('are', 'VBP'), ('we', 'PRP'), ('mortals', 'NNS'), ('.', '.'), ('We', 'PRP'), ('walk', 'VBP'), Tree('NP', [('the', 'DT'), ('path', 'NN')]), ('in', 'IN'), ('between', 'IN'), (',', ','), ('and', 'CC'), ('that', 'IN'), ('demands', 'VBZ'), Tree('NP', [('discipline', 'NN')]), ('.', '.'), ("''", "''"), ('Atreus', 'NNP'), (',', ','), Tree('NP', [('eager', 'NN')]), ('to', 'TO'), ('prove', 'VB'), ('himself', 'PRP'), (',', ','), ('responded', 'VBD'), ('with', 'IN'), Tree('NP', [('youthful', 'JJ'), ('defiance', 'NN')]), (',', ','), ('``', '``'), ('But', 'CC'), ('Father', 'NNP'), (',', ','), ('I', 'PRP'), ('can', 'MD'), ('handle', 'VB'), ('it', 'PRP'), ('!', '.'), ('I', 'PRP'), ("'m", 'VBP'), ('not', 'RB'), Tree('NP', [('a', 'DT'), ('child', 'NN')]), ('anymore', 'RB'), ('.', '.'), ("''", "''"), ('Kratos', 'NNP'), (',', ','), ('recalling', 'VBG'), ('his', 'PRP$'), Tree('NP', [('own', 'JJ'), ('tumultuous', 'JJ'), ('journey', 'NN')]), (',', ','), ('retorted', 'VBD'), (',', ','), ('``', '``'), ('You', 'PRP'), ('are', 'VBP'), ('not', 'RB'), ('ready', 'JJ'), ('.', '.'), ('The', 'DT'), ('gods', 'NNS'), ('will', 'MD'), ('test', 'VB'), ('you', 'PRP'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('consequences', 'NNS'), ('of', 'IN'), Tree('NP', [('arrogance', 'NN')]), ('are', 'VBP'), ('severe', 'JJ'), ('.', '.'), ("''", "''"), ('As', 'IN'), ('they', 'PRP'), ('ventured', 'VBD'), ('through', 'IN'), ('the', 'DT'), ('treacherous', 'JJ'), ('realms', 'NNS'), (',', ','), ('the', 'DT'), ('echoes', 'NNS'), ('of', 'IN'), ('their', 'PRP$'), ('dialogues', 'NNS'), ('revealed', 'VBD'), Tree('NP', [('a', 'DT'), ('complex', 'JJ'), ('father-son', 'JJ'), ('dynamic', 'NN')]), (',', ','), ('blending', 'VBG'), Tree('NP', [('vulnerability', 'NN')]), ('with', 'IN'), Tree('NP', [('strength', 'NN')]), (',', ','), ('shaping', 'VBG'), ('their', 'PRP$'), Tree('NP', [('epic', 'NN')]), Tree('NP', [('odyssey', 'NN')]), ('in', 'IN'), Tree('NP', [('the', 'DT'), ('world', 'NN')]), ('of', 'IN'), ('gods', 'NNS'), ('and', 'CC'), ('monsters', 'NNS'), ('.', '.')]),
#  Tree('NP', [('deep', 'JJ'), ('voice', 'NN')]),
#  Tree('NP', [('resonating', 'NN')]),
#  Tree('NP', [('son', 'NN')]),
#  Tree('NP', [('tone', 'NN')]),
#  Tree('NP', [('the', 'DT'), ('path', 'NN')]),
#  Tree('NP', [('discipline', 'NN')]),
#  Tree('NP', [('eager', 'NN')]),
#  Tree('NP', [('youthful', 'JJ'), ('defiance', 'NN')]),
#  Tree('NP', [('a', 'DT'), ('child', 'NN')]),
#  Tree('NP', [('own', 'JJ'), ('tumultuous', 'JJ'), ('journey', 'NN')]),
#  Tree('NP', [('arrogance', 'NN')]),
#  Tree('NP', [('a', 'DT'), ('complex', 'JJ'), ('father-son', 'JJ'), ('dynamic', 'NN')]),
#  Tree('NP', [('vulnerability', 'NN')]),
#  Tree('NP', [('strength', 'NN')]),
#  Tree('NP', [('epic', 'NN')]),
#  Tree('NP', [('odyssey', 'NN')]),
#  Tree('NP', [('the', 'DT'), ('world', 'NN')])]

# %%
noun_phrases = [subtree.leaves() for subtree in chunks.subtrees() if subtree.label() == 'NP']
noun_phrases
# Out:
# [[('deep', 'JJ'), ('voice', 'NN')],
#  [('resonating', 'NN')],
#  [('son', 'NN')],
#  [('tone', 'NN')],
#  [('the', 'DT'), ('path', 'NN')],
#  [('discipline', 'NN')],
#  [('eager', 'NN')],
#  [('youthful', 'JJ'), ('defiance', 'NN')],
#  [('a', 'DT'), ('child', 'NN')],
#  [('own', 'JJ'), ('tumultuous', 'JJ'), ('journey', 'NN')],
#  [('arrogance', 'NN')],
#  [('a', 'DT'), ('complex', 'JJ'), ('father-son', 'JJ'), ('dynamic', 'NN')],
#  [('vulnerability', 'NN')],
#  [('strength', 'NN')],
#  [('epic', 'NN')],
#  [('odyssey', 'NN')],
#  [('the', 'DT'), ('world', 'NN')]]
